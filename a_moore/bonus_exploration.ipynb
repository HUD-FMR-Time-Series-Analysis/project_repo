# %%
import pandas as pd
import numpy as np

import requests
import re
from wrangle_rapid import rapid_api_mvp_prep

# %%
url = 'https://raw.githubusercontent.com/OpenDataDE/State-zip-code-GeoJSON/master/tx_texas_zip_codes_geo.min.json'

response = requests.get(url)

data = response.json()

# %%
d = pd.DataFrame()

keys = list(data['features'][0]['properties'].keys())
keys = keys + list(data['features'][0]['geometry'].keys())
# keys

# %%
d = pd.DataFrame(columns=keys, index=None)
d
# Out:
# Empty DataFrame
# Columns: [STATEFP10, ZCTA5CE10, GEOID10, CLASSFP10, MTFCC10, FUNCSTAT10, ALAND10, AWATER10, INTPTLAT10, INTPTLON10, PARTFLG10, type, coordinates]
# Index: []

# %%
# Now I need to get all the information in one dictionary
base_dict = data['features'][0]['properties']
base_dict.update(data['features'][0]['geometry'])
# base_dict

# %%
# make it programmaric to get all the items in the dictionary up here
base_dict = {}
for i, d in enumerate(data['features']):
    base_dict[i] = data['features'][i]['properties']
    base_dict[i].update(data['features'][i]['geometry'])

# %%
geo_df = pd.DataFrame(base_dict).T

# %%
geo_df.rename({'ZCTA5CE10':'zipcode'}, axis=1, inplace=True)

# %%
zipcodes = list(df.zipcode.value_counts().index)

# %%
filtered_geo_df = geo_df[geo_df.zipcode.isin(zipcodes)]

# %%
filtered_geo_df.GEOID10.value_counts()
# Out:
# 4878114    1
# 4878003    1
# 4878109    1
# 4878124    1
# 4878009    1
# 4878108    1
# 4878154    1
# 4878002    1
# 4878121    1
# 4878160    1
# 4878073    1
# 4878201    1
# 4878203    1
# 4878205    1
# 4878070    1
# 4878163    1
# 4878113    1
# 4878055    1
# 4878148    1
# 4878101    1
# 4878064    1
# 4878052    1
# 4878161    1
# 4878204    1
# 4878006    1
# 4878069    1
# 4878063    1
# 4878023    1
# 4878207    1
# 4878130    1
# 4878132    1
# 4878152    1
# 4878202    1
# 4878015    1
# 4878140    1
# 4878010    1
# 4878147    1
# 4878112    1
# 4878123    1
# 4878155    1
# 4878133    1
# Name: GEOID10, dtype: int64

# %%
df = rapid_api_mvp_prep('corey.csv')

# %%
chdb_df = pd.read_csv('chdb_data_tract_tx_v16.csv')
# Out:
# /var/folders/fj/7fbysvvn7956npcj9d4mxfxw0000gn/T/ipykernel_9946/1312788093.py:1: DtypeWarning: Columns (23) have mixed types. Specify dtype option on import or set low_memory=False.
#   chdb_df = pd.read_csv('chdb_data_tract_tx_v16.csv')

# %%
chdb_df.metric_name.value_counts()
# Out:
# Air pollution - ozone                        59448
# High school completion                        4954
# Uninsured                                     4954
# Unemployment - annual, neighborhood-level     4954
# Rent burden                                   4954
# Racial/ethnic diversity                       4954
# Income Inequality                             4954
# Housing with potential lead risk              4954
# Lead exposure risk index                      4954
# Broadband connection                          4954
# Children in Poverty                           4954
# Frequent physical distress                    3814
# High blood pressure                           3814
# Walkability                                   3814
# Smoking                                       3814
# Routine checkup, 18+                          3814
# COVID local risk index                        3814
# Credit Insecurity Index                       3814
# ...

# %%
chdb_df[chdb_df.county_name.isin'Bexar County']
# Out:
#        state_abbr  state_fips  ... version  suggested_citation
# 57             TX          48  ...    16.0                 NaN
# 58             TX          48  ...    16.0                 NaN
# 59             TX          48  ...    16.0                 NaN
# 60             TX          48  ...    16.0                 NaN
# 61             TX          48  ...    16.0                 NaN
# ...           ...         ...  ...     ...                 ...
# 174347         TX          48  ...    16.0                 NaN
# 174348         TX          48  ...    16.0                 NaN
# 174349         TX          48  ...    16.0                 NaN
# 174350         TX          48  ...    16.0                 NaN
# 174351         TX          48  ...    16.0                 NaN
#
# [13792 rows x 24 columns]

# %% [markdown]
# # Questions to ask of the data
# *
