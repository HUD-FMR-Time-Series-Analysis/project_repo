# %% [markdown]
# ## HUD API Testing Notebook

# %%
import numpy as np
import pandas as pd
import os
import requests
from env import hud_token

# %%
url = 'https://www.huduser.gov/hudapi/public/fmr/listCounties/TX'
headers = {
    'Authorization': f'Bearer {hud_token}'
}

response = requests.get(url, headers=headers)

# Process the response...

# %%
response.status_code
# Out:
# 200

# %%
response
# Out:
# <Response [200]>

# %%
response.text
# Out:
# '[{"state_code":"TX","fips_code":"4800199999","county_name":"Anderson County","town_name":"","category":"County"},{"state_code":"TX","fips_code":"4800399999","county_name":"Andrews County","town_name":"","category":"County"},{"state_code":"TX","fips_code":"4800599999","county_name":"Angelina County","town_name":"","category":"County"},{"state_code":"TX","fips_code":"4800799999","county_name":"Aransas County","town_name":"","category":"County"},{"state_code":"TX","fips_code":"4800999999","county_name":"Archer County","town_name":"","category":"County"},{"state_code":"TX","fips_code":"4801199999","county_name":"Armstrong County","town_name":"","category":"County"},{"state_code":"TX","fips_code":"4801399999","county_name":"Atascosa County","town_name":"","category":"County"},{"state_code":"TX","fips_code":"4801599999","county_name":"Austin County","town_name":"","category":"County"},{"state_code":"TX","fips_code":"4801799999","county_name":"Bailey County","town_name":"","category":"County"},{"state_code":"TX","fips_code":"4801999999","county_name":"Bandera County","town_name":"","category":"County"},{"state_code":"TX","fips_code":"4802199999","county_name":"Bastrop County","town_name":"","category":"County"},{"state_code":"TX","fips_code":"4802399999","county_name":"Baylor County","town_name":"","category":"County"},{"state_code":"TX","fips_code":"4802599999","county_name":"Bee County","town_name":"","category":"County"},{"state_code":"TX","fips_code":"4802799999","county_name":"Bell County","town_name":"","category":"County"},{"state_code":"TX","fips_code":"4802999999","county_name":"Bexar County","town_name":"","category":"County"},{"state_code":"TX","fips_code":"4803199999","county_name":"Blanco County","town_name":"","category":"County"},{"state_code":"TX","fips_code":"4803399999","county_name":"Borden County","town_name":"","category":"County"},{"state_code":"TX","fips_code":"4803599999","county_name":"Bosque County","town_name":"","category":"County"},{"state_code":"TX","fips_code":"4803799999","county_name":"Bowie County","town_name":"","category":"County"},{"state_code":"TX","fips_code":"4803999999","county_name":"Brazoria County","town_name":"","category":"County"},{"state_code":"TX","fips_code":"4804199999","county_name":"Brazos County","town_name":"","category":"County"},{"state_code":"TX","fips_code":"4804399999","county_name":"Brewster County","town_name":"","category":"County"},{"state_code":"TX","fips_code":"4804599999","county_name":"Briscoe County","town_name":"","category":"County"},{"state_code":"TX","fips_code":"4804799999","county_name":"Brooks County","town_name":"","category":"County"},{"state_code":"TX","fips_code":"4804999999","county_name":"Brown County","town_name":"","category":"County"},{"state_code":"TX","fips_code":"4805199999","county_name":"Burleson County","town_name":"","category":"County"},{"state_code":"TX","fips_code":"4805399999","county_name":"Burnet County","town_name":"","category":"County"},{"state_code":"TX","fips_code":"4805599999","county_name":"Caldwell County","town_name":"","category":"County"},{"state_code":"TX","fips_code":"4805799999","county_name":"Calhoun County","town_name":"","category":"County"},{"state_code":"TX","fips_code":"4805999999","county_name":"Callahan County","town_name":"","category":"County"},{"state_code":"TX","fips_code":"4806199999","county_name":"Cameron County","town_name":"","category":"County"},{"state_code":"TX","fips_code":"4806399999","county_name":"Camp County","town_name":"","category":"County"},{"state_code":"TX","fips_code":"4806599999","county_name":"Carson County","town_name":"","category":"County"},{"state_code":"TX","fips_code":"4806799999","county_name":"Cass County","town_name":"","category":"County"},{"state_code":"TX","fips_code":"4806999999","county_name":"Castro County","town_name":"","category":"County"},{"state_code":"TX","fips_code":"4807199999","county_name":"Chambers County","town_name":"","category":"County"},{"state_code":"TX","fi ...

# %%
# ok, up and running with a response. Texas state code is 48, which is shared with Census Data

# %%
# Now to see if we can get the data we're interested in
# start with a list of counties in Texas
url = 'https://www.huduser.gov/hudapi/public/fmr/listCounties/TX'
headers = {
    'Authorization': f'Bearer {hud_token}'
}

response = requests.get(url, headers=headers)

# %%
response.text
# Out:
# '[{"state_code":"TX","fips_code":"4800199999","county_name":"Anderson County","town_name":"","category":"County"},{"state_code":"TX","fips_code":"4800399999","county_name":"Andrews County","town_name":"","category":"County"},{"state_code":"TX","fips_code":"4800599999","county_name":"Angelina County","town_name":"","category":"County"},{"state_code":"TX","fips_code":"4800799999","county_name":"Aransas County","town_name":"","category":"County"},{"state_code":"TX","fips_code":"4800999999","county_name":"Archer County","town_name":"","category":"County"},{"state_code":"TX","fips_code":"4801199999","county_name":"Armstrong County","town_name":"","category":"County"},{"state_code":"TX","fips_code":"4801399999","county_name":"Atascosa County","town_name":"","category":"County"},{"state_code":"TX","fips_code":"4801599999","county_name":"Austin County","town_name":"","category":"County"},{"state_code":"TX","fips_code":"4801799999","county_name":"Bailey County","town_name":"","category":"County"},{"state_code":"TX","fips_code":"4801999999","county_name":"Bandera County","town_name":"","category":"County"},{"state_code":"TX","fips_code":"4802199999","county_name":"Bastrop County","town_name":"","category":"County"},{"state_code":"TX","fips_code":"4802399999","county_name":"Baylor County","town_name":"","category":"County"},{"state_code":"TX","fips_code":"4802599999","county_name":"Bee County","town_name":"","category":"County"},{"state_code":"TX","fips_code":"4802799999","county_name":"Bell County","town_name":"","category":"County"},{"state_code":"TX","fips_code":"4802999999","county_name":"Bexar County","town_name":"","category":"County"},{"state_code":"TX","fips_code":"4803199999","county_name":"Blanco County","town_name":"","category":"County"},{"state_code":"TX","fips_code":"4803399999","county_name":"Borden County","town_name":"","category":"County"},{"state_code":"TX","fips_code":"4803599999","county_name":"Bosque County","town_name":"","category":"County"},{"state_code":"TX","fips_code":"4803799999","county_name":"Bowie County","town_name":"","category":"County"},{"state_code":"TX","fips_code":"4803999999","county_name":"Brazoria County","town_name":"","category":"County"},{"state_code":"TX","fips_code":"4804199999","county_name":"Brazos County","town_name":"","category":"County"},{"state_code":"TX","fips_code":"4804399999","county_name":"Brewster County","town_name":"","category":"County"},{"state_code":"TX","fips_code":"4804599999","county_name":"Briscoe County","town_name":"","category":"County"},{"state_code":"TX","fips_code":"4804799999","county_name":"Brooks County","town_name":"","category":"County"},{"state_code":"TX","fips_code":"4804999999","county_name":"Brown County","town_name":"","category":"County"},{"state_code":"TX","fips_code":"4805199999","county_name":"Burleson County","town_name":"","category":"County"},{"state_code":"TX","fips_code":"4805399999","county_name":"Burnet County","town_name":"","category":"County"},{"state_code":"TX","fips_code":"4805599999","county_name":"Caldwell County","town_name":"","category":"County"},{"state_code":"TX","fips_code":"4805799999","county_name":"Calhoun County","town_name":"","category":"County"},{"state_code":"TX","fips_code":"4805999999","county_name":"Callahan County","town_name":"","category":"County"},{"state_code":"TX","fips_code":"4806199999","county_name":"Cameron County","town_name":"","category":"County"},{"state_code":"TX","fips_code":"4806399999","county_name":"Camp County","town_name":"","category":"County"},{"state_code":"TX","fips_code":"4806599999","county_name":"Carson County","town_name":"","category":"County"},{"state_code":"TX","fips_code":"4806799999","county_name":"Cass County","town_name":"","category":"County"},{"state_code":"TX","fips_code":"4806999999","county_name":"Castro County","town_name":"","category":"County"},{"state_code":"TX","fips_code":"4807199999","county_name":"Chambers County","town_name":"","category":"County"},{"state_code":"TX","fi ...

# %%
# fips for Bexar County is 
# {"state_code":"TX","fips_code":"4802999999","county_name":"Bexar County","town_name":"","category":"County"}

# %%
response
# Out:
# <Response [200]>

# %%
# let's try this with a Metropolitan Statistical Area of San Antonio
url = 'https://www.huduser.gov/hudapi/public/fmr/listMetroAreas'
headers = {
    'Authorization': f'Bearer {hud_token}'
}

response = requests.get(url, headers=headers)

# %%
response.text
# Out:
# '[{"cbsa_code":"METRO10180M10180","area_name":"Abilene, TX MSA","category":"MetroArea"},{"cbsa_code":"METRO29180N22001","area_name":"Acadia Parish, LA HUD Metro FMR Area","category":"MetroArea"},{"cbsa_code":"METRO10380M10380","area_name":"Aguadilla-Isabela, PR HUD Metro FMR Area","category":"MetroArea"},{"cbsa_code":"METRO10420M10420","area_name":"Akron, OH MSA","category":"MetroArea"},{"cbsa_code":"METRO10500M10500","area_name":"Albany, GA MSA","category":"MetroArea"},{"cbsa_code":"METRO10540M10540","area_name":"Albany, OR MSA","category":"MetroArea"},{"cbsa_code":"METRO10580M10580","area_name":"Albany-Schenectady-Troy, NY MSA","category":"MetroArea"},{"cbsa_code":"METRO10740M10740","area_name":"Albuquerque, NM MSA","category":"MetroArea"},{"cbsa_code":"METRO10780M10780","area_name":"Alexandria, LA MSA","category":"MetroArea"},{"cbsa_code":"METRO14540N21003","area_name":"Allen County, KY HUD Metro FMR Area","category":"MetroArea"},{"cbsa_code":"METRO10900M10900","area_name":"Allentown-Bethlehem-Easton, PA HUD Metro FMR Area","category":"MetroArea"},{"cbsa_code":"METRO11020M11020","area_name":"Altoona, PA MSA","category":"MetroArea"},{"cbsa_code":"METRO11100M11100","area_name":"Amarillo, TX HUD Metro FMR Area","category":"MetroArea"},{"cbsa_code":"METRO11180M11180","area_name":"Ames, IA MSA","category":"MetroArea"},{"cbsa_code":"METRO11260M11260","area_name":"Anchorage, AK HUD Metro FMR Area","category":"MetroArea"},{"cbsa_code":"METRO26900M11300","area_name":"Anderson, IN HUD Metro FMR Area","category":"MetroArea"},{"cbsa_code":"METRO24860M11340","area_name":"Anderson, SC HUD Metro FMR Area","category":"MetroArea"},{"cbsa_code":"METRO11460M11460","area_name":"Ann Arbor, MI MSA","category":"MetroArea"},{"cbsa_code":"METRO11500M11500","area_name":"Anniston-Oxford-Jacksonville, AL MSA","category":"MetroArea"},{"cbsa_code":"METRO11540M11540","area_name":"Appleton, WI MSA","category":"MetroArea"},{"cbsa_code":"METRO18580N48007","area_name":"Aransas County, TX HUD Metro FMR Area","category":"MetroArea"},{"cbsa_code":"METRO11640MM0470","area_name":"Arecibo, PR HUD Metro FMR Area","category":"MetroArea"},{"cbsa_code":"METRO38300N42005","area_name":"Armstrong County, PA HUD Metro FMR Area","category":"MetroArea"},{"cbsa_code":"METRO11700M11700","area_name":"Asheville, NC HUD Metro FMR Area","category":"MetroArea"},{"cbsa_code":"METRO41700N48013","area_name":"Atascosa County, TX HUD Metro FMR Area","category":"MetroArea"},{"cbsa_code":"METRO12020M12020","area_name":"Athens-Clarke County, GA MSA","category":"MetroArea"},{"cbsa_code":"METRO12060M12060","area_name":"Atlanta-Sandy Springs-Roswell, GA HUD Metro FMR Area","category":"MetroArea"},{"cbsa_code":"METRO12100M12100","area_name":"Atlantic City-Hammonton, NJ MSA","category":"MetroArea"},{"cbsa_code":"METRO12220M12220","area_name":"Auburn-Opelika, AL MSA","category":"MetroArea"},{"cbsa_code":"METRO12260M12260","area_name":"Augusta-Richmond County, GA-SC HUD Metro FMR Area","category":"MetroArea"},{"cbsa_code":"METRO26420N48015","area_name":"Austin County, TX HUD Metro FMR Area","category":"MetroArea"},{"cbsa_code":"METRO12420M12420","area_name":"Austin-Round Rock, TX MSA","category":"MetroArea"},{"cbsa_code":"METRO27260N12003","area_name":"Baker County, FL HUD Metro FMR Area","category":"MetroArea"},{"cbsa_code":"METRO12540M12540","area_name":"Bakersfield, CA MSA","category":"MetroArea"},{"cbsa_code":"METRO12580M12580","area_name":"Baltimore-Columbia-Towson, MD MSA","category":"MetroArea"},{"cbsa_code":"METRO12620MM0730","area_name":"Bangor, ME HUD Metro FMR Area","category":"MetroArea"},{"cbsa_code":"METRO12700M12700","area_name":"Barnstable Town, MA MSA","category":"MetroArea"},{"cbsa_code":"METRO41980N72923","area_name":"Barranquitas-Aibonito, PR HUD Metro FMR Area","category":"MetroArea"},{"cbsa_code":"METRO24340N26015","area_name":"Barry County, MI HUD Metro FMR Area","category":"MetroArea"},{"cbsa_code":"METRO28140N29013","area_name":"Bates County, MO HUD Metro FMR Area","cate ...

# %%
# for San Antonio MSA is:
#{"cbsa_code":"METRO41700M41700","area_name":"San Antonio-New Braunfels, TX HUD Metro FMR Area","category":"MetroArea"}

# %%
# let's try this with a Metropolitan Statistical Area of San Antonio
url = 'https://www.huduser.gov/hudapi/public/fmr/data/METRO41700M41700'
headers = {
    'Authorization': f'Bearer {hud_token}'
}

response = requests.get(url, headers=headers)

# %%
response.text
# Out:
# '{"data":{"county_name":"","counties_msa":"Bandera County, TX; Bexar County, TX; Comal County, TX; Guadalupe County, TX; and Wilson County, TX","town_name":"","metro_status":"1","metro_name":"San Antonio-New Braunfels, TX","area_name":"San Antonio-New Braunfels, TX HUD Metro FMR Area","smallarea_status":"1","year":"2023","basicdata":[{"zip_code":"78002","Efficiency":760,"One-Bedroom":870,"Two-Bedroom":1060,"Three-Bedroom":1350,"Four-Bedroom":1640},{"zip_code":"78003","Efficiency":790,"One-Bedroom":910,"Two-Bedroom":1110,"Three-Bedroom":1410,"Four-Bedroom":1710},{"zip_code":"78006","Efficiency":1030,"One-Bedroom":1240,"Two-Bedroom":1530,"Three-Bedroom":1870,"Four-Bedroom":2340},{"zip_code":"78009","Efficiency":840,"One-Bedroom":890,"Two-Bedroom":1170,"Three-Bedroom":1530,"Four-Bedroom":1570},{"zip_code":"78010","Efficiency":790,"One-Bedroom":910,"Two-Bedroom":1100,"Three-Bedroom":1400,"Four-Bedroom":1710},{"zip_code":"78015","Efficiency":1380,"One-Bedroom":1610,"Two-Bedroom":1960,"Three-Bedroom":2470,"Four-Bedroom":3040},{"zip_code":"78023","Efficiency":1370,"One-Bedroom":1580,"Two-Bedroom":1910,"Three-Bedroom":2430,"Four-Bedroom":2960},{"zip_code":"78039","Efficiency":590,"One-Bedroom":630,"Two-Bedroom":830,"Three-Bedroom":1080,"Four-Bedroom":1120},{"zip_code":"78052","Efficiency":690,"One-Bedroom":820,"Two-Bedroom":960,"Three-Bedroom":1190,"Four-Bedroom":1510},{"zip_code":"78054","Efficiency":910,"One-Bedroom":1050,"Two-Bedroom":1270,"Three-Bedroom":1620,"Four-Bedroom":1970},{"zip_code":"78055","Efficiency":610,"One-Bedroom":700,"Two-Bedroom":850,"Three-Bedroom":1080,"Four-Bedroom":1320},{"zip_code":"78063","Efficiency":940,"One-Bedroom":1090,"Two-Bedroom":1320,"Three-Bedroom":1680,"Four-Bedroom":2050},{"zip_code":"78064","Efficiency":860,"One-Bedroom":1060,"Two-Bedroom":1200,"Three-Bedroom":1460,"Four-Bedroom":1980},{"zip_code":"78069","Efficiency":590,"One-Bedroom":720,"Two-Bedroom":830,"Three-Bedroom":1020,"Four-Bedroom":1340},{"zip_code":"78070","Efficiency":1110,"One-Bedroom":1280,"Two-Bedroom":1550,"Three-Bedroom":1970,"Four-Bedroom":2400},{"zip_code":"78073","Efficiency":700,"One-Bedroom":820,"Two-Bedroom":980,"Three-Bedroom":1230,"Four-Bedroom":1530},{"zip_code":"78101","Efficiency":890,"One-Bedroom":1030,"Two-Bedroom":1250,"Three-Bedroom":1590,"Four-Bedroom":1930},{"zip_code":"78108","Efficiency":1370,"One-Bedroom":1580,"Two-Bedroom":1920,"Three-Bedroom":2440,"Four-Bedroom":2980},{"zip_code":"78109","Efficiency":1120,"One-Bedroom":1290,"Two-Bedroom":1560,"Three-Bedroom":1980,"Four-Bedroom":2420},{"zip_code":"78112","Efficiency":840,"One-Bedroom":970,"Two-Bedroom":1180,"Three-Bedroom":1500,"Four-Bedroom":1830},{"zip_code":"78113","Efficiency":860,"One-Bedroom":1000,"Two-Bedroom":1200,"Three-Bedroom":1520,"Four-Bedroom":1870},{"zip_code":"78114","Efficiency":820,"One-Bedroom":940,"Two-Bedroom":1140,"Three-Bedroom":1450,"Four-Bedroom":1770},{"zip_code":"78115","Efficiency":1010,"One-Bedroom":1160,"Two-Bedroom":1410,"Three-Bedroom":1790,"Four-Bedroom":2190},{"zip_code":"78121","Efficiency":940,"One-Bedroom":1080,"Two-Bedroom":1310,"Three-Bedroom":1670,"Four-Bedroom":2030},{"zip_code":"78123","Efficiency":790,"One-Bedroom":920,"Two-Bedroom":1110,"Three-Bedroom":1410,"Four-Bedroom":1720},{"zip_code":"78124","Efficiency":860,"One-Bedroom":990,"Two-Bedroom":1200,"Three-Bedroom":1530,"Four-Bedroom":1860},{"zip_code":"78130","Efficiency":1000,"One-Bedroom":1150,"Two-Bedroom":1400,"Three-Bedroom":1780,"Four-Bedroom":2170},{"zip_code":"78131","Efficiency":1020,"One-Bedroom":1180,"Two-Bedroom":1430,"Three-Bedroom":1820,"Four-Bedroom":2220},{"zip_code":"78132","Efficiency":1040,"One-Bedroom":1200,"Two-Bedroom":1450,"Three-Bedroom":1840,"Four-Bedroom":2250},{"zip_code":"78133","Efficiency":920,"One-Bedroom":1060,"Two-Bedroom":1290,"Three-Bedroom":1640,"Four-Bedroom":2000},{"zip_code":"78140","Efficiency":770,"One-Bedroom":890,"Two-Bedroom":1080,"Three-Bedroom":1370,"Four-Bedroom":1670},{"zip_code":"78143","Efficiency":780,"One-Bedr ...

# %%
# ok, got the first year of data for San Antonio/NewBraunfels MSA,
# now try to get other years

# %%
url = 'https://www.huduser.gov/hudapi/public/fmr/data/METRO41700M41700?year=2018'
headers = {
    'Authorization': f'Bearer {hud_token}'
}

response = requests.get(url, headers=headers)

# %%
response.text
# Out:
# '{"data":{"county_name":"","counties_msa":"Bandera County, TX; Bexar County, TX; Comal County, TX; Guadalupe County, TX; and Wilson County, TX","town_name":"","metro_status":"1","metro_name":"San Antonio-New Braunfels, TX MSA","area_name":"San Antonio-New Braunfels, TX HUD Metro FMR Area","smallarea_status":"1","year":"2018","basicdata":[{"zip_code":"78002","Efficiency":570,"One-Bedroom":710,"Two-Bedroom":880,"Three-Bedroom":1170,"Four-Bedroom":1420},{"zip_code":"78003","Efficiency":640,"One-Bedroom":790,"Two-Bedroom":980,"Three-Bedroom":1300,"Four-Bedroom":1580},{"zip_code":"78006","Efficiency":760,"One-Bedroom":930,"Two-Bedroom":1170,"Three-Bedroom":1480,"Four-Bedroom":2050},{"zip_code":"78009","Efficiency":560,"One-Bedroom":690,"Two-Bedroom":870,"Three-Bedroom":1240,"Four-Bedroom":1500},{"zip_code":"78010","Efficiency":610,"One-Bedroom":750,"Two-Bedroom":940,"Three-Bedroom":1240,"Four-Bedroom":1500},{"zip_code":"78015","Efficiency":1010,"One-Bedroom":1250,"Two-Bedroom":1560,"Three-Bedroom":2030,"Four-Bedroom":2590},{"zip_code":"78023","Efficiency":830,"One-Bedroom":1020,"Two-Bedroom":1270,"Three-Bedroom":1680,"Four-Bedroom":2040},{"zip_code":"78039","Efficiency":560,"One-Bedroom":690,"Two-Bedroom":870,"Three-Bedroom":1150,"Four-Bedroom":1380},{"zip_code":"78052","Efficiency":560,"One-Bedroom":690,"Two-Bedroom":870,"Three-Bedroom":1150,"Four-Bedroom":1380},{"zip_code":"78054","Efficiency":650,"One-Bedroom":800,"Two-Bedroom":1000,"Three-Bedroom":1310,"Four-Bedroom":1600},{"zip_code":"78055","Efficiency":600,"One-Bedroom":740,"Two-Bedroom":920,"Three-Bedroom":1220,"Four-Bedroom":1480},{"zip_code":"78063","Efficiency":600,"One-Bedroom":740,"Two-Bedroom":920,"Three-Bedroom":1210,"Four-Bedroom":1470},{"zip_code":"78064","Efficiency":600,"One-Bedroom":690,"Two-Bedroom":920,"Three-Bedroom":1180,"Four-Bedroom":1380},{"zip_code":"78069","Efficiency":560,"One-Bedroom":690,"Two-Bedroom":870,"Three-Bedroom":1150,"Four-Bedroom":1380},{"zip_code":"78070","Efficiency":860,"One-Bedroom":1060,"Two-Bedroom":1320,"Three-Bedroom":1750,"Four-Bedroom":2130},{"zip_code":"78073","Efficiency":560,"One-Bedroom":690,"Two-Bedroom":870,"Three-Bedroom":1150,"Four-Bedroom":1380},{"zip_code":"78101","Efficiency":730,"One-Bedroom":900,"Two-Bedroom":1130,"Three-Bedroom":1490,"Four-Bedroom":1800},{"zip_code":"78108","Efficiency":970,"One-Bedroom":1200,"Two-Bedroom":1500,"Three-Bedroom":1980,"Four-Bedroom":2410},{"zip_code":"78109","Efficiency":790,"One-Bedroom":980,"Two-Bedroom":1220,"Three-Bedroom":1620,"Four-Bedroom":1960},{"zip_code":"78112","Efficiency":640,"One-Bedroom":790,"Two-Bedroom":990,"Three-Bedroom":1310,"Four-Bedroom":1590},{"zip_code":"78113","Efficiency":560,"One-Bedroom":690,"Two-Bedroom":870,"Three-Bedroom":1150,"Four-Bedroom":1380},{"zip_code":"78114","Efficiency":560,"One-Bedroom":690,"Two-Bedroom":870,"Three-Bedroom":1150,"Four-Bedroom":1380},{"zip_code":"78115","Efficiency":670,"One-Bedroom":830,"Two-Bedroom":1040,"Three-Bedroom":1370,"Four-Bedroom":1660},{"zip_code":"78121","Efficiency":710,"One-Bedroom":880,"Two-Bedroom":1100,"Three-Bedroom":1450,"Four-Bedroom":1760},{"zip_code":"78123","Efficiency":600,"One-Bedroom":740,"Two-Bedroom":930,"Three-Bedroom":1230,"Four-Bedroom":1490},{"zip_code":"78124","Efficiency":640,"One-Bedroom":800,"Two-Bedroom":990,"Three-Bedroom":1310,"Four-Bedroom":1590},{"zip_code":"78130","Efficiency":720,"One-Bedroom":870,"Two-Bedroom":1080,"Three-Bedroom":1460,"Four-Bedroom":1750},{"zip_code":"78131","Efficiency":730,"One-Bedroom":900,"Two-Bedroom":1130,"Three-Bedroom":1490,"Four-Bedroom":1810},{"zip_code":"78132","Efficiency":680,"One-Bedroom":840,"Two-Bedroom":1050,"Three-Bedroom":1380,"Four-Bedroom":1680},{"zip_code":"78133","Efficiency":720,"One-Bedroom":890,"Two-Bedroom":1110,"Three-Bedroom":1470,"Four-Bedroom":1780},{"zip_code":"78140","Efficiency":560,"One-Bedroom":690,"Two-Bedroom":870,"Three-Bedroom":1150,"Four-Bedroom":1380},{"zip_code":"78143","Efficiency":600,"One-Bedroom":740,"Two-Bedroom":930,"Th ...

# %%
data = response.json()

# %%
HUD_SA_2023 = pd.DataFrame(data['data']['basicdata'])

# %%
HUD_SA_2023
# Out:
#     zip_code  Efficiency  One-Bedroom  Two-Bedroom  Three-Bedroom  \
# 0      78002         760          870         1060           1350
# 1      78003         790          910         1110           1410
# 2      78006        1030         1240         1530           1870
# 3      78009         840          890         1170           1530
# 4      78010         790          910         1100           1400
# ..       ...         ...          ...          ...            ...
# 131    78670         910         1030         1220           1560
# 132    78676        1200         1330         1560           2000
# 133    78883         670          760          940           1200
# 134    78884         790          910         1100           1400
# 135    78885         790          910         1100           1400
#
#      Four-Bedroom
# 0            1640
# 1            1710
# 2            2340
# 3            1570
# 4            1710
# ..            ...
# 131          1850
# 132          2320
# 133          1430
# 134          1710
# 135          1710
#
# [136 rows x 6 columns]

# %%
from datetime import datetime

def get_year_list():
    '''
    This function creates a list of years beginning with 2018 up to one year before the
    current year. 2018 correlates to the first year that HUD MSA Small Area data was available
    so that starting point is fixed. The function adds a new year at the end of the calendar year. 
    HUD generally publishes new rates in September for implementation with the Federal Fiscal Year 
    which begins October 1st of year prior. This lag to the start of the calendar year gives time 
    to sure that the database is updated before adding the next year to the query. As the HUD API 
    uses a different query format for current year, this list will not include the current year as
    that is not specified to default to the current year
    
    Arguments: None
    
    Returns: A list of years from 2018 to present.
    '''
    start_year = 2018  # desired starting year
    current_year = datetime.now().year

    year_range = list(range(start_year, current_year + 1))
    
    return year_range

# %%
get_year_list()
# Out:
# [2018, 2019, 2020, 2021, 2022, 2023]

# %%
def get_entity_data(entity_id):
    '''
    This function takes in a single HUD entity (in this case Metropolitan Statistical Area)
    and requests the Fair Market Rent Small Area Data for that entity for the current year. This current year response is converted to a .json and then a DataFrame and then
    each prior is queried and and concatenated to the original df. Requires a HUD API User Token
    which can be acquired here: https://www.huduser.gov/portal/dataset/fmr-api.html
    Entity_ids can be found here: https://www.huduser.gov/portal/datasets/geotools.html
    
    Arguments: a HUD entity id
    
    Returns: a DataFrame of Fair Market Rent rates for each ZIP code in 
    '''
    header = {'Authorization': f'Bearer {hud_token}'}

    years = get_year_list()
    df = pd.DataFrame()

    for year in years:
        url = f'https://www.huduser.gov/hudapi/public/fmr/data/{entity_id}?year={year}'
        response = requests.get(url, headers=header)
        data = response.json()
        dum = pd.DataFrame(data['data']['basic_data'])
        dum['year'] = data['data']['year']
        dum['entity_id'] = entity_id
        dum['area_name'] = data['data']['area_name']
        df = pd.concat([df, dum])

    return df

# %%
get_entity_data('METRO41700M41700')
# Out:
#     zip_code  Efficiency  One-Bedroom  Two-Bedroom  Three-Bedroom  \
# 0      78002         570          710          880           1170
# 1      78003         640          790          980           1300
# 2      78006         760          930         1170           1480
# 3      78009         560          690          870           1240
# 4      78010         610          750          940           1240
# ..       ...         ...          ...          ...            ...
# 131    78670         910         1030         1220           1560
# 132    78676        1200         1330         1560           2000
# 133    78883         670          760          940           1200
# 134    78884         790          910         1100           1400
# 135    78885         790          910         1100           1400
#
#      Four-Bedroom  year         entity_id  \
# 0            1420  2018  METRO41700M41700
# 1            1580  2018  METRO41700M41700
# 2            2050  2018  METRO41700M41700
# 3            1500  2018  METRO41700M41700
# 4            1500  2018  METRO41700M41700
# ..            ...   ...               ...
# 131          1850  2023  METRO41700M41700
# 132          2320  2023  METRO41700M41700
# 133          1430  2023  METRO41700M41700
# 134          1710  2023  METRO41700M41700
# 135          1710  2023  METRO41700M41700
#
#                                             area_name
# 0    San Antonio-New Braunfels, TX HUD Metro FMR Area
# 1    San Antonio-New Braunfels, TX HUD Metro FMR Area
# 2    San Antonio-New Braunfels, TX HUD Metro FMR Area
# 3    San Antonio-New Braunfels, TX HUD Metro FMR Area
# 4    San Antonio-New Braunfels, TX HUD Metro FMR Area
# ..                                                ...
# 131  San Antonio-New Braunfels, TX HUD Metro FMR Area
# 132  San Antonio-New Braunfels, TX HUD Metro FMR Area
# 133  San Antonio-New Braunfels, TX HUD Metro FMR Area
# 134  San Antonio-New Braunfels, TX HUD Metro FMR Area
# 135  San Antonio-New Braunfels, TX HUD Metro FMR Area
#
# [812 rows x 9 columns]

# %%
# ok, we have data from 2018 to 2023. Now, to put all of these years into one DF

# need to add a column year and concat on axis = 0

def get_hud_data(entity_ids):
    '''
    This function takes in a list of HUD entities (in this case Metropolitan Statistical Areas)
    and requests the Fair Market Rent Small Area Data for each entity. It then creates a new 
    column "entity_id" and concatenates the all of the entity DataFrames into a single DataFrame.
    Entity_ids can be found here: https://www.huduser.gov/portal/datasets/geotools.html
    
    Arguments: a list of HUD entity_ids
    
    Returns: a DataFrame of HUD FMR for each ZIP code and year from 2018-present for all HUD
            entities in entity_id list.
    '''
    df = pd.DataFrame()
    
    for entity_id in entity_ids:
        
        df = pd.concat([df, get_entity_data(entity_id)])
        
    return df

# %%
entity_ids = ['METRO41700M41700']

# %%
df = get_hud_data(entity_ids)
df
# Out:
#     zip_code  Efficiency  One-Bedroom  Two-Bedroom  Three-Bedroom  \
# 0      78002         570          710          880           1170
# 1      78003         640          790          980           1300
# 2      78006         760          930         1170           1480
# 3      78009         560          690          870           1240
# 4      78010         610          750          940           1240
# ..       ...         ...          ...          ...            ...
# 807    78670         910         1030         1220           1560
# 808    78676        1200         1330         1560           2000
# 809    78883         670          760          940           1200
# 810    78884         790          910         1100           1400
# 811    78885         790          910         1100           1400
#
#      Four-Bedroom  year         entity_id  \
# 0            1420  2018  METRO41700M41700
# 1            1580  2018  METRO41700M41700
# 2            2050  2018  METRO41700M41700
# 3            1500  2018  METRO41700M41700
# 4            1500  2018  METRO41700M41700
# ..            ...   ...               ...
# 807          1850  2023  METRO41700M41700
# 808          2320  2023  METRO41700M41700
# 809          1430  2023  METRO41700M41700
# 810          1710  2023  METRO41700M41700
# 811          1710  2023  METRO41700M41700
#
#                                             area_name
# 0    San Antonio-New Braunfels, TX HUD Metro FMR Area
# 1    San Antonio-New Braunfels, TX HUD Metro FMR Area
# 2    San Antonio-New Braunfels, TX HUD Metro FMR Area
# 3    San Antonio-New Braunfels, TX HUD Metro FMR Area
# 4    San Antonio-New Braunfels, TX HUD Metro FMR Area
# ..                                                ...
# 807  San Antonio-New Braunfels, TX HUD Metro FMR Area
# 808  San Antonio-New Braunfels, TX HUD Metro FMR Area
# 809  San Antonio-New Braunfels, TX HUD Metro FMR Area
# 810  San Antonio-New Braunfels, TX HUD Metro FMR Area
# 811  San Antonio-New Braunfels, TX HUD Metro FMR Area
#
# [812 rows x 9 columns]

# %%
# check out basic info
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 812 entries, 0 to 811
# Data columns (total 9 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   zip_code       812 non-null    object
#  1   Efficiency     812 non-null    int64
#  2   One-Bedroom    812 non-null    int64
#  3   Two-Bedroom    812 non-null    int64
#  4   Three-Bedroom  812 non-null    int64
#  5   Four-Bedroom   812 non-null    int64
#  6   year           812 non-null    object
#  7   entity_id      812 non-null    object
#  8   area_name      812 non-null    object
# dtypes: int64(5), object(4)
# memory usage: 57.2+ KB

# %%
# let's see if we can cast year to date time.
df['year'] = pd.to_datetime(df.year)
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 812 entries, 0 to 811
# Data columns (total 9 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   zip_code       812 non-null    object
#  1   Efficiency     812 non-null    int64
#  2   One-Bedroom    812 non-null    int64
#  3   Two-Bedroom    812 non-null    int64
#  4   Three-Bedroom  812 non-null    int64
#  5   Four-Bedroom   812 non-null    int64
#  6   year           812 non-null    datetime64[ns]
#  7   entity_id      812 non-null    object
#  8   area_name      812 non-null    object
# dtypes: datetime64[ns](1), int64(5), object(3)
# memory usage: 57.2+ KB

# %%
# ok, now to set the date as index
df.set_index('year', inplace=True)

# %%
df.head()
# Out:
#            zip_code  Efficiency  One-Bedroom  Two-Bedroom  Three-Bedroom  \
# year
# 2023-01-01    78670         910         1030         1220           1560
# 2023-01-01    78676        1200         1330         1560           2000
# 2023-01-01    78883         670          760          940           1200
# 2023-01-01    78884         790          910         1100           1400
# 2023-01-01    78885         790          910         1100           1400
#
#             Four-Bedroom         entity_id  \
# year
# 2023-01-01          1850  METRO41700M41700
# 2023-01-01          2320  METRO41700M41700
# 2023-01-01          1430  METRO41700M41700
# 2023-01-01          1710  METRO41700M41700
# 2023-01-01          1710  METRO41700M41700
#
#                                                    area_name
# year
# 2023-01-01  San Antonio-New Braunfels, TX HUD Metro FMR Area
# 2023-01-01  San Antonio-New Braunfels, TX HUD Metro FMR Area
# 2023-01-01  San Antonio-New Braunfels, TX HUD Metro FMR Area
# 2023-01-01  San Antonio-New Braunfels, TX HUD Metro FMR Area
# 2023-01-01  San Antonio-New Braunfels, TX HUD Metro FMR Area

# %%
cols = df.columns.tolist()

# %%
cols
# Out:
# ['zip_code',
#  'Efficiency',
#  'One-Bedroom',
#  'Two-Bedroom',
#  'Three-Bedroom',
#  'Four-Bedroom',
#  'entity_id',
#  'area_name']

# %%
cols = [col.lower().replace('-', '_') for col in cols]

# %%
cols
# Out:
# ['zip_code',
#  'efficiency',
#  'one_bedroom',
#  'two_bedroom',
#  'three_bedroom',
#  'four_bedroom',
#  'entity_id',
#  'area_name']

# %%
new_cols = dict(zip(df.columns, cols))
new_cols
# Out:
# {'zip_code': 'zip_code',
#  'Efficiency': 'efficiency',
#  'One-Bedroom': 'one_bedroom',
#  'Two-Bedroom': 'two_bedroom',
#  'Three-Bedroom': 'three_bedroom',
#  'Four-Bedroom': 'four_bedroom',
#  'entity_id': 'entity_id',
#  'area_name': 'area_name'}

# %%
df = df.rename(columns=new_cols)
df.head()
# Out:
#            zip_code  efficiency  one_bedroom  two_bedroom  three_bedroom  \
# year
# 2018-01-01    78002         570          710          880           1170
# 2018-01-01    78003         640          790          980           1300
# 2018-01-01    78006         760          930         1170           1480
# 2018-01-01    78009         560          690          870           1240
# 2018-01-01    78010         610          750          940           1240
#
#             four_bedroom         entity_id  \
# year
# 2018-01-01          1420  METRO41700M41700
# 2018-01-01          1580  METRO41700M41700
# 2018-01-01          2050  METRO41700M41700
# 2018-01-01          1500  METRO41700M41700
# 2018-01-01          1500  METRO41700M41700
#
#                                                    area_name
# year
# 2018-01-01  San Antonio-New Braunfels, TX HUD Metro FMR Area
# 2018-01-01  San Antonio-New Braunfels, TX HUD Metro FMR Area
# 2018-01-01  San Antonio-New Braunfels, TX HUD Metro FMR Area
# 2018-01-01  San Antonio-New Braunfels, TX HUD Metro FMR Area
# 2018-01-01  San Antonio-New Braunfels, TX HUD Metro FMR Area

# %%
df.drop(columns='zip_code')
# Out:
#             efficiency  one_bedroom  two_bedroom  three_bedroom  four_bedroom  \
# year
# 2018-01-01         570          710          880           1170          1420
# 2018-01-01         640          790          980           1300          1580
# 2018-01-01         760          930         1170           1480          2050
# 2018-01-01         560          690          870           1240          1500
# 2018-01-01         610          750          940           1240          1500
# ...                ...          ...          ...            ...           ...
# 2023-01-01         910         1030         1220           1560          1850
# 2023-01-01        1200         1330         1560           2000          2320
# 2023-01-01         670          760          940           1200          1430
# 2023-01-01         790          910         1100           1400          1710
# 2023-01-01         790          910         1100           1400          1710
#
#                    entity_id                                         area_name
# year
# 2018-01-01  METRO41700M41700  San Antonio-New Braunfels, TX HUD Metro FMR Area
# 2018-01-01  METRO41700M41700  San Antonio-New Braunfels, TX HUD Metro FMR Area
# 2018-01-01  METRO41700M41700  San Antonio-New Braunfels, TX HUD Metro FMR Area
# 2018-01-01  METRO41700M41700  San Antonio-New Braunfels, TX HUD Metro FMR Area
# 2018-01-01  METRO41700M41700  San Antonio-New Braunfels, TX HUD Metro FMR Area
# ...                      ...                                               ...
# 2023-01-01  METRO41700M41700  San Antonio-New Braunfels, TX HUD Metro FMR Area
# 2023-01-01  METRO41700M41700  San Antonio-New Braunfels, TX HUD Metro FMR Area
# 2023-01-01  METRO41700M41700  San Antonio-New Braunfels, TX HUD Metro FMR Area
# 2023-01-01  METRO41700M41700  San Antonio-New Braunfels, TX HUD Metro FMR Area
# 2023-01-01  METRO41700M41700  San Antonio-New Braunfels, TX HUD Metro FMR Area
#
# [812 rows x 7 columns]

# %%
df_grouped = df.groupby(['entity_id', 'year']).agg(
    {'zip_code':'count', 'efficiency':'mean', 'one_bedroom':'mean', 'two_bedroom':'mean', 
     'three_bedroom':'mean', 'four_bedroom':'mean', 'entity_id':'first', 'area_name':'first'})

# %%
df_grouped
# Out:
#                              zip_code  efficiency  one_bedroom  two_bedroom  \
# entity_id        year
# METRO41700M41700 2018-01-01       135  678.592593   835.925926       1000.0
#                  2019-01-01       135  708.074074   867.925926       1040.0
#                  2020-01-01       134  720.671642   874.179104       1040.0
#                  2021-01-01       136  782.500000   936.617647       1110.0
#                  2022-01-01       136  833.970588   982.867647       1160.0
#                  2023-01-01       136  934.779412  1077.426471       1270.0
#
#                              three_bedroom  four_bedroom         entity_id  \
# entity_id        year
# METRO41700M41700 2018-01-01    1380.222222   1677.037037  METRO41700M41700
#                  2019-01-01    1418.444444   1735.851852  METRO41700M41700
#                  2020-01-01    1407.835821   1734.701493  METRO41700M41700
#                  2021-01-01    1480.735294   1834.411765  METRO41700M41700
#                  2022-01-01    1530.367647   1884.632353  METRO41700M41700
#                  2023-01-01    1658.676471   2017.647059  METRO41700M41700
#
#                                                                     area_name
# entity_id        year
# METRO41700M41700 2018-01-01  San Antonio-New Braunfels, TX HUD Metro FMR Area
#                  2019-01-01  San Antonio-New Braunfels, TX HUD Metro FMR Area
#                  2020-01-01  San Antonio-New Braunfels, TX HUD Metro FMR Area
#                  2021-01-01  San Antonio-New Braunfels, TX HUD Metro FMR Area
#                  2022-01-01  San Antonio-New Braunfels, TX HUD Metro FMR Area
#                  2023-01-01  San Antonio-New Braunfels, TX HUD Metro FMR Area
